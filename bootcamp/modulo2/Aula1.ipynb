# %% [markdown]
# ## Caderno de exploração dos dados do datasus 2008 pra frente

# %% [markdown]
# # Aula 1

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv'
dados = pd.read_csv(url, #endereço do dataframe
                    thousands='.', #separador de milhar por ponto
                    decimal=',', #separador de decimal é por virgula
                    encoding='ISO-8859-1', #o codec do arquivo é iso-8859-1
                    skipfooter=12, # iginora as ultimas 12 linhas do arquivo
                    skiprows=3, # ignora as 3 primeiras linhas do arquivo
                    sep=';', # separador é por ponto e virgula
                    engine='python' ) 
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan     2020/Fev  \
# 0        -        -        -  ...   8660753.05   8326416.32   8413784.42
# 1        -        -        -  ...   2959569.09   3261123.88   2981264.22
# 2        -        -        -  ...  14923380.22  15939561.23  15138110.70
# 3        -        -        -  ...   2889969.87   3084561.08   2967159.04
# 4        -        -        -  ...  35222625.80  37009819.17  34635702.52
#
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan  \
# 22        -        -        -        -  ...  88720873.59  97474362.62
# 23        -        -        -        -  ...  17844511.04  18653296.92
# 24        -        -        -        -  ...  13827706.20  15445693.74
# 25        -        -        -        -  ...  34050298.55  36312121.02
# 26        -        -        -        -  ...  19207148.01  20429067.27
#
#        2020/Fev     2020/Mar     2020/Abr     2020/Mai     2020/Jun  \
# ...

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
pd.options.display.float_format = "{:.2f}".format #configura a impressão global para 2 casas decimais

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados['2008/Jan'].describe()
# Out:
# count           27.00
# mean      75697225.19
# std      198450569.38
# min         808448.39
# 25%        8257222.37
# 50%       16503978.22
# 75%       52126749.14
# max     1023564534.21
# Name: 2008/Jan, dtype: float64

# %%
dados['2008/Jan']
# Out:
# 0       1829559.71
# 1       1731744.62
# 2      11419210.08
# 3        808448.39
# 4      21762104.16
# 5       1329876.61
# 6       5136474.61
# 7      21551600.33
# 8      11375419.37
# 9      32444328.54
# 10     11763899.23
# 11     16599004.84
# 12     51219113.60
# 13     16503978.22
# 14      5439985.99
# 15     73336297.08
# 16    205912743.65
# 17     16212109.41
# 18    250564959.99
# 19   1023564534.21
# 20     58081334.45
# 21     53034384.67
# 22     51064610.03
# 23      8301006.10
# 24      8213438.64
# 25     74063828.22
# 26     10561085.46
# Name: 2008/Jan, dtype: float64

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
dados.plot(x='Unidade da Federação', 
           y='2008/Ago', 
           kind='bar', 
           figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as tiker

ax = dados.plot(x='Unidade da Federação', 
                y='2008/Ago', 
                kind='bar', 
                figsize=(10,7))
ax.yaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
#https://matplotlib.org/3.2.1/gallery/ticks_and_spines/tick-formatters.html

plt.title('Valor por unidade da federação')
plt.show()

# %%
dados_ago_08 = dados.sort_values(by=['2008/Ago'], ascending=True)

# %%
ax = dados_ago_08.plot(x='Unidade da Federação', 
                       y='2008/Ago', 
                       kind='barh', 
                       figsize=(10,7))
ax.xaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
#https://matplotlib.org/3.2.1/gallery/ticks_and_spines/tick-formatters.html

plt.title('Valor por unidade da federação')
plt.show()

# %% [markdown]
# ## Desafio: escolher um título mais descritivo, que passe a mensagem adequada.

# %%
ax = dados_ago_08.plot(x='Unidade da Federação', 
                        y='2008/Ago', 
                        kind='barh', 
                        figsize=(15,7))

ax.xaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
#https://matplotlib.org/3.2.1/gallery/ticks_and_spines/tick-formatters.html

plt.title('Valor gasto por estado em Agosto de 2008')
plt.show()

# %% [markdown]
# ## Desafio: faça a mesma análise pro mês mais recente.

# %%
dados_dez_16 = dados.sort_values(by=['2016/Dez'], ascending=True)
ax = dados_dez_16.plot(x='Unidade da Federação', 
                       y='2016/Dez' ,
                       kind='barh', 
                       figsize=(15,7), width=0.8)

ax.xaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
#https://matplotlib.org/3.2.1/gallery/ticks_and_spines/tick-formatters.html

plt.title('Valor gasto por estado em Dezembro de 2016', fontsize=16)
plt.show()

# %% [markdown]
# # Aula 2

# %%
dados[['2008/Ago', '2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
#pegar dados só de onde tem dados preenchidos#
##############################################

dados.mean() # a média só retorna resultado de onde encontrou dados preenchidos
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist() #retorna somente as colunas que tem dados preenchidos
colunas_usaveis.insert(0,'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2019/Nov  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  8948605.66
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3174249.43
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 14781332.42
# 3   808448.39   771687.83   876091.18   896952.53  ...  3121104.71
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 35555518.00
#
#      2019/Dez    2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai  \
# ...

# %%
usaveis = usaveis.set_index('Unidade da Federação')
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
usaveis['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
usaveis = usaveis.drop('Total', axis=1)

# %%
ax = usaveis.T.plot(figsize=(10,6))
plt.show(ax)

# %% [markdown]
# ## Desafio: reposicionar a legenda. Dentro? Fora? Onde?

# %%
ax = usaveis.T.plot(figsize=(10,7))
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), shadow=True, ncol=1)
ax.yaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
plt.title('Gasto dos Estados por Mês', fontsize=16)
plt.show(ax)

# %% [markdown]
# ## Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %%
cinco_estados = usaveis.loc[['15 Pará', '26 Pernambuco', '31 Minas Gerais', '52 Goiás','42 Santa Catarina']].copy()

# %%
ax = cinco_estados.T.plot(figsize=(10,7))
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), shadow=True, ncol=1)
ax.yaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
plt.title('Gasto dos Estados por Mês', fontsize=16)
plt.show(ax)

# %% [markdown]
# # Aula 3

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[:5].T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
import numpy as np
seed = np.random.seed(687942)

usaveis.sample(n=7).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
usaveis['Total'] = usaveis.sum(axis=1)#axis = 1 soma os valores da linha
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
ordenado_por_total = usaveis.sort_values(by='Total', ascending=False)
ordenado_por_total = ordenado_por_total.drop('Total', axis=1)
usaveis = usaveis.drop('Total', axis=1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1023564534.21 172834914.73 170481849.56
# 31 Minas Gerais      43429517.54  205912743.65  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  250564959.99  44122593.19  42892665.52
#
# ...

# %%
ordenado_por_total.head().T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
# ordenado_por_regiao = ordenado_por_total.copy()
# ordenado_por_regiao['regiao'] = (ordenado_por_total.index).str[0]
# ordenado_por_regiao[['regiao']].head(1)

# %%
# regiao = ordenado_por_regiao.groupby(['regiao']).sum()
# regiao

# %%
# #Configurações da legenda do gráfico (região)
# ax = regiao.T.plot(figsize=(10,7))
# handles, _ = ax.get_legend_handles_labels()
# ax.legend(handles, ['Norte', 'Nordeste', 'Sudeste','Sul','Centro-oeste'], fontsize=12)

# %%
ordenado_por_total.columns
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2019/Out', '2019/Nov', '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar',
#        '2020/Abr', '2020/Mai', '2020/Jun', '2020/Jul'],
#       dtype='object', length=156)

# %%
colunas_interessadas = ordenado_por_total.columns[6:]#elimina as 6 primeiras colunas
ordenado_por_total[colunas_interessadas].head().T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Desafio: mudar palete de cores com o matplotlib

# %%
ax = usaveis.T.plot(figsize=(10,7), cmap='Dark2', linewidth=2) 
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), shadow=True, ncol=1)
ax.yaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
plt.title('Gasto dos Estados por Mês', fontsize=16)


plt.show(ax)

# %% [markdown]
# ## Desafio: adicionar uma coluna mostrando a região de cada estado

# %%
# usaveis
usaveis['regiao'] = (usaveis.index).str[0]
usaveis["regiao"].replace({'1': 'Norte', 
                           '2':'Nordeste', 
                           '3':'Sudeste',
                           '4':'Sul',
                           '5':'Centro-Oeste'}, inplace=True)
usaveis['regiao']
# Out:
# Unidade da Federação
# 11 Rondônia                      Norte
# 12 Acre                          Norte
# 13 Amazonas                      Norte
# 14 Roraima                       Norte
# 15 Pará                          Norte
# 16 Amapá                         Norte
# 17 Tocantins                     Norte
# 21 Maranhão                   Nordeste
# 22 Piauí                      Nordeste
# 23 Ceará                      Nordeste
# 24 Rio Grande do Norte        Nordeste
# 25 Paraíba                    Nordeste
# 26 Pernambuco                 Nordeste
# 27 Alagoas                    Nordeste
# 28 Sergipe                    Nordeste
# 29 Bahia                      Nordeste
# 31 Minas Gerais                Sudeste
# 32 Espírito Santo              Sudeste
# 33 Rio de Janeiro              Sudeste
# 35 São Paulo                   Sudeste
# 41 Paraná                          Sul
# 42 Santa Catarina                  Sul
# 43 Rio Grande do Sul               Sul
# ...

# %%
regiao = usaveis.copy()
regiao = regiao.groupby(['regiao']).sum()
regiao.T.plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Desafio: deixar o gráfico mais bonito. A mensagem mais clara.

# %%
ordenado_por_total_normalizado = ordenado_por_total[ordenado_por_total.columns[6:]]
ordenado_por_total_normalizado.head(1)
# Out:
#                          2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# 35 São Paulo         172834914.73 170481849.56 170278285.95 172402180.59
#
#                          2008/Jun     2008/Jul     2008/Ago     2008/Set  \
# Unidade da Federação
# 35 São Paulo         175416595.83 179525002.10 179898070.22 180082203.71
#
#                          2008/Out     2008/Nov  ...     2019/Out     2019/Nov  \
# Unidade da Federação                            ...
# 35 São Paulo         191685220.08 190539738.80  ... 303382527.10 282391773.21
#
#                          2019/Dez     2020/Jan     2020/Fev     2020/Mar  \
# Unidade da Federação
# 35 São Paulo         272697695.04 301991167.67 271356784.04 276606288.92
#
#                          2020/Abr     2020/Mai     2020/Jun     2020/Jul
# Unidade da Federação
# 35 São Paulo         251696362.66 302857660.98 299060851.62 282709570.31
#
# [1 rows x 150 columns]

# %%
# ordenado_por_total
ax = ordenado_por_total_normalizado.T.plot(figsize=(10,7))
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), shadow=True, ncol=1)
ax.yaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
ax.set_xlabel('Periodo', fontsize=14)
ax.set_ylabel('Valores', fontsize=14)
plt.title('Gasto dos Estados por Mês', fontsize=16)
plt.show(ax)

# %% [markdown]
# ## Desafio: adicione seu estado aos 5 estados existentes e plote

# %% [markdown]
# ### complemento do desafio: melhorar a escala

# %%
# ordenado_por_total
seis_estados = list(ordenado_por_total_normalizado.index[:5])
seis_estados.append('42 Santa Catarina')
# ordenado_por_total_normalizado.T[seis_estados].plot()

ax = ordenado_por_total_normalizado.T[seis_estados].plot(figsize=(10,7))
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), shadow=True, ncol=1)
ax.yaxis.set_major_formatter(tiker.StrMethodFormatter('{x:,.0f}') )
ax.set_xlabel('Periodo', fontsize=14)
ax.set_ylabel('Valores', fontsize=14)
plt.title('Gasto dos Estados por Mês', fontsize=16)
plt.show(ax)

# %% [markdown]
# ## Desafio: googlar os casos de dengue no Brasil e se reflete nos gastos

# %% [markdown]
# encontrei no [site](https://antigo.saude.gov.br/saude-de-a-z/dengue/situacao-epidemiologica-dados) do governo alguns dados sobre a dengue, utilizei os dados de Incidência de Dengue. Brasil, Grandes Regiões e Unidades Federadas, 1998 a 2018

# %%
#lendo dados do excel que está na url do governo
url = 'https://antigo.saude.gov.br/images/xlsx/2019/julho/05/Serie-Historica-1998-a-2018-INCIDENCIA-DENGUE-SITE.xlsx'
incidencia_dengue = pd.read_excel(url, skipfooter=5, skiprows=2)

#eliminando linhas com os dados da região
incidencia_dengue_estados = incidencia_dengue[~incidencia_dengue['Região e UF'].str.contains('Região') == True]

#adicionando nome do estado como index
incidencia_dengue_estados = incidencia_dengue_estados.set_index('Região e UF')

#eliminando linhas com os dados de estados
incidencia_dengue_regiao = incidencia_dengue[~incidencia_dengue['Região e UF'].str.contains('Região') == False]

#adicionando nome da região como index
incidencia_dengue_regiao = incidencia_dengue_regiao.set_index('Região e UF')

#filtrando pelos dados que estão entre 2008 a 2018
incidencia_dengue_estados = incidencia_dengue_estados[incidencia_dengue_estados.columns[10:]]
incidencia_dengue_regiao = incidencia_dengue_regiao[incidencia_dengue_regiao.columns[10:]]

# %%
incidencia_dengue_estados.head()
# Out:
#                2008    2009    2010    2011   2012   2013    2014   2015  \
# Região e UF
# Rondônia     373.40 1345.76 1298.89  206.03 207.04 505.26  113.52 126.45
# Acre         365.40 2800.91 4793.34 2571.71 315.37 330.73 3577.90 672.95
# Amazonas     226.15   51.72  215.96 1779.17 143.89 468.29  171.95  97.89
# Roraima     1193.85  756.35 1684.87  322.10 399.13 193.62  225.98 220.75
# Pará         210.97  102.87  205.35  253.79 207.69 114.58   55.47  96.28
#
#               2016   2017   2018
# Região e UF
# Rondônia    439.37 116.96  30.50
# Acre        290.60 219.38 795.96
# Amazonas    206.31  95.70  60.19
# Roraima      48.65  54.15  22.03
# Pará        132.74  92.98  47.01

# %%
incidencia_dengue_regiao
# Out:
#                       2008   2009    2010   2011   2012    2013   2014  \
# Região e UF
# Região Norte        312.75 379.63  621.72 752.61 257.88  291.22 280.25
# Região Nordeste     339.79 232.87  333.17 368.04 413.51  273.07 160.07
# Região Sudeste      350.58 122.73  594.79 449.64 308.63 1087.10 366.14
# Região Sul            7.62   7.15  153.39 131.37  17.21  232.34  79.22
# Região Centro-Oeste 323.43 785.77 1536.84 369.47 471.51 1770.51 763.29
#
#                        2015    2016   2017   2018
# Região e UF
# Região Norte         181.97  223.27 120.60  98.20
# Região Nordeste      582.37  574.28 146.00 118.00
# Região Sudeste      1230.42 1000.95  60.60  85.40
# Região Sul           178.11  248.54   8.50   8.20
# Região Centro-Oeste 1518.47 1332.62 497.40 634.50

# %%
ax = incidencia_dengue_regiao.T.plot(figsize=(15,7))

ax.legend(loc='upper center', bbox_to_anchor=(1.1, 1), shadow=True, ncol=1)
plt.title('Incidentes de dengue por região', fontsize=16)
plt.show()

# %%
ax = usaveis[usaveis.columns[6:]].groupby('regiao').sum().T.plot(figsize = (15,7))
plt.title('Gasto por região', fontsize=16)
plt.show()

# %% [markdown]
# #### é possivel perceber que o gráfico de gasto mantem um padrão similar em todas as regiões, o mesmo não se aplica ao gráfico de incidência de dengue, não foi possivel achar uma correlação entre os dados.

# %% [markdown]
# ## Desafio: plotar só os estados do sudeste e ver se afetou com um pico em 2012/2013 de forma smilar esses estados

# %%
group_region = usaveis[usaveis.columns[6:]].groupby('regiao')

usaveis_sudeste = list(group_region.get_group('Sudeste').T.index[:-1])

# %%
ax = group_region.get_group('Sudeste')[usaveis_sudeste].T.plot(figsize = (15,7))
plt.show()

# %% [markdown]
# ## Desafio: adicionar seu estado escolhido novamente e deixe o gráfico lindo e informativo com suas informações claras

# %%
def reformat_large_tick_values(tick_val, pos):
    """
    Turns large tick values (in the billions, millions and thousands) such as 4500 into 4.5K and also appropriately turns 4000 into 4K (no zero after the decimal).
    """
    if tick_val >= 1000000000:
        val = round(tick_val/1000000000, 1)
        new_tick_format = '{:}B'.format(val)
    elif tick_val >= 1000000:
        val = round(tick_val/1000000, 1)
        new_tick_format = '{:}M'.format(val)
    elif tick_val >= 1000:
        val = round(tick_val/1000, 1)
        new_tick_format = '{:}K'.format(val)
    elif tick_val < 1000:
        new_tick_format = round(tick_val, 1)
    else:
        new_tick_format = tick_val

    # make new_tick_format into a string value
    new_tick_format = str(new_tick_format)
    
    # code below will keep 4.5M as is but change values such as 4.0M to 4M since that zero after the decimal isn't needed
    index_of_decimal = new_tick_format.find(".")
    
    if index_of_decimal != -1:
        value_after_decimal = new_tick_format[index_of_decimal+1]
        if value_after_decimal == "0":
            # remove the 0 after the decimal point since it's not needed
            new_tick_format = new_tick_format[0:index_of_decimal] + new_tick_format[index_of_decimal+2:]
            
    return new_tick_format

# %% [markdown]
# ## Desafio: adicionar seu estado escolhido novamente e deixe o gráfico lindo e informativo com suas informações claras

# %%
# ordenado_por_total
seis_estados = list(ordenado_por_total_normalizado.index[:5])
seis_estados.append('42 Santa Catarina')
# ordenado_por_total_normalizado.T[seis_estados].plot()

ax = ordenado_por_total_normalizado.T[seis_estados].plot(figsize=(10,7), linewidth=2)
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), shadow=True, ncol=1)
ax.yaxis.set_major_formatter(tiker.FuncFormatter(reformat_large_tick_values))
ax.set_xlabel('Periodo', fontsize=14)
ax.set_ylabel('Valores', fontsize=14)
plt.title('Gasto dos Estados por Mês', fontsize=16)
plt.show(ax)

# %% [markdown]
# # Aula 4

# %%
ordenado_por_total_normalizado.head().T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total = ordenado_por_total / 1000000
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0,350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(100,350)
# Out:
# (100.0, 350.0)

# %% [markdown]
# # Aula5

# %%
mes_mais_recente = ordenado_por_total.columns[-2]
mes_mais_recente
# Out:
# '2020/Jun'

# %%
gastos_do_mes_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mes_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           299.06
# 31 Minas Gerais        135.98
# 41 Paraná               92.90
# 43 Rio Grande do Sul    89.02
# 33 Rio de Janeiro       77.60
# Name: 2020/Jun, dtype: float64

# %%
gastos_do_mes_mais_recente.plot()
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
gastos_do_mes_mais_recente.plot(kind='pie', figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='2020/Jun'>

# %% [markdown]
# Horrores da pizza:
#
# - legenda está horrível
# - número de fatias inacreditável
#
# Já estamos com uma vantagem que o gráfico veio ordenado

# %%
#plotagem de pizza sem ordenação
gastos_do_mes_mais_recente.sample(frac=1).plot(kind='pie', figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='2020/Jun'>

# %% [markdown]
# Horrores da pizza sem ordenação:
#
# - legenda está horrível
# - número de fatias inacreditável
# - não da pra saber visualmente qual é maior ou menor já que está desordenado
# - cores repetidas
# - muito ruim para definir ordem
# - péssimo para comparar

# %%
# visualização simples
gastos_do_mes_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             299.06
# 31 Minas Gerais          135.98
# 41 Paraná                 92.90
# 43 Rio Grande do Sul      89.02
# 33 Rio de Janeiro         77.60
# 29 Bahia                  65.16
# 26 Pernambuco             68.15
# 42 Santa Catarina         56.50
# 23 Ceará                  42.15
# 52 Goiás                  34.44
# 15 Pará                   35.40
# 21 Maranhão               31.13
# 32 Espírito Santo         27.45
# 24 Rio Grande do Norte    20.22
# 25 Paraíba                19.67
# 53 Distrito Federal       23.48
# 50 Mato Grosso do Sul     15.84
# 22 Piauí                  15.38
# 27 Alagoas                14.28
# 51 Mato Grosso            14.59
# 13 Amazonas               17.51
# 28 Sergipe                 6.71
# 17 Tocantins               5.02
# 11 Rondônia                9.19
# 12 Acre                    2.20
# 14 Roraima                 3.22
# 16 Amapá                   2.70
# Name: 2020/Jun, dtype: float64

# %%
#gastos relativos

gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc['33 Rio de Janeiro']
# Out:
# Unidade da Federação
# 35 São Paulo             3.85
# 31 Minas Gerais          1.75
# 41 Paraná                1.20
# 43 Rio Grande do Sul     1.15
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.84
# 26 Pernambuco            0.88
# 42 Santa Catarina        0.73
# 23 Ceará                 0.54
# 52 Goiás                 0.44
# 15 Pará                  0.46
# 21 Maranhão              0.40
# 32 Espírito Santo        0.35
# 24 Rio Grande do Norte   0.26
# 25 Paraíba               0.25
# 53 Distrito Federal      0.30
# 50 Mato Grosso do Sul    0.20
# 22 Piauí                 0.20
# 27 Alagoas               0.18
# 51 Mato Grosso           0.19
# 13 Amazonas              0.23
# 28 Sergipe               0.09
# 17 Tocantins             0.06
# 11 Rondônia              0.12
# 12 Acre                  0.03
# 14 Roraima               0.04
# 16 Amapá                 0.03
# Name: 2020/Jun, dtype: float64

# %%
gastos_do_mes_mais_recente.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
gastos_do_mes_mais_recente = gastos_do_mes_mais_recente.sort_values(ascending=False)
gastos_do_mes_mais_recente.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %% [markdown]
# ## Desafio: Criar a tabela de comparação com seu estado (ou de preferẽncia se não for do Brasil)

# %%
gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc['35 São Paulo']
# Out:
# Unidade da Federação
# 35 São Paulo             1.00
# 31 Minas Gerais          0.45
# 41 Paraná                0.31
# 43 Rio Grande do Sul     0.30
# 33 Rio de Janeiro        0.26
# 26 Pernambuco            0.23
# 29 Bahia                 0.22
# 42 Santa Catarina        0.19
# 23 Ceará                 0.14
# 15 Pará                  0.12
# 52 Goiás                 0.12
# 21 Maranhão              0.10
# 32 Espírito Santo        0.09
# 53 Distrito Federal      0.08
# 24 Rio Grande do Norte   0.07
# 25 Paraíba               0.07
# 13 Amazonas              0.06
# 50 Mato Grosso do Sul    0.05
# 22 Piauí                 0.05
# 51 Mato Grosso           0.05
# 27 Alagoas               0.05
# 11 Rondônia              0.03
# 28 Sergipe               0.02
# 17 Tocantins             0.02
# 14 Roraima               0.01
# 16 Amapá                 0.01
# 12 Acre                  0.01
# Name: 2020/Jun, dtype: float64

# %% [markdown]
# ## Desafio: documentação do matplotlib e pandas para colocar grid no gráfico

# %%
#gastos_do_mes_mais_recente


gastos_do_mes_mais_recente = gastos_do_mes_mais_recente.sort_values(ascending=False)
ax = gastos_do_mes_mais_recente.plot(kind='bar', figsize=(15,10))
plt.grid(color='gray',linestyle='-')

# %% [markdown]
# ## Desafio: gráfico de barrs do gasto dos outros estados em função ao seu estado

# %%
em_funcao_meu_estado = gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc['35 São Paulo']
ax = em_funcao_meu_estado.to_frame().plot(kind='bar', figsize=(10,5))

plt.show()

# %% [markdown]
# ## Desafio: Fazer o cálculo proporcional a população do seu estado e mais um a sua escolha.

# %% [markdown]
# #### Fonte dos dados populacionais retiradas do IBGE do ano de 2020:
# - [São Paulo](https://www.ibge.gov.br/cidades-e-estados/sp.html) - 46.289.333
# - [Santa Catarina](https://www.ibge.gov.br/cidades-e-estados/sc.html) - 7.252.502

# %%
proporcional_por_populacao = (gastos_do_mes_mais_recente[['35 São Paulo', '42 Santa Catarina']]).to_frame()
proporcional_por_populacao
# Out:
#                       2020/Jun
# Unidade da Federação
# 35 São Paulo            299.06
# 42 Santa Catarina        56.50

# %%
proporcional_por_populacao['populacao'] = ([46289333, 7252502])
proporcional_por_populacao
# Out:
#                       2020/Jun  populacao
# Unidade da Federação
# 35 São Paulo            299.06   46289333
# 42 Santa Catarina        56.50    7252502

# %%
#proporção em percentual
proporcional_por_populacao['proporcao'] = ((proporcional_por_populacao['2020/Jun'].astype(int)*1000)/proporcional_por_populacao['populacao'])*10000
proporcional_por_populacao
# Out:
#                       2020/Jun  populacao  proporcao
# Unidade da Federação
# 35 São Paulo            299.06   46289333      64.59
# 42 Santa Catarina        56.50    7252502      77.21

# %%
ax = proporcional_por_populacao['proporcao'].plot(kind='bar', figsize=(8,8))
plt.title('Gasto por estado proporcional a população', fontsize=16)
plt.xticks(rotation=0)
ax.set_xlabel('Estado', fontsize=14)
ax.set_ylabel('Percentual', fontsize=14)

plt.show()

# %% [markdown]
# ## Desafio: Faça uma análise dos dados analisados, levante hipóteses e compartilhe com a gente no Discord.

# %% [markdown]
# #### Fonte de dados utiulizada - IBGE
# [Brasil](https://www.ibge.gov.br/cidades-e-estados)

# %%
#comparar o idh com o gasto por população
dados_ibge = pd.read_excel('dados_demograficos_ibge_brasil.xlsx', skiprows=2, skipfooter=15)
dados_ibge.head()
# Out:
#      UF [-]  Código [-] Gentílico [-]                       Governador [2019]  \
# 0      Acre          12       acriano                  GLADSON DE LIMA CAMELI
# 1   Alagoas          27      alagoano  JOSE RENAN VASCONCELOS CALHEIROS FILHO
# 2     Amapá          16     amapaense            ANTONIO WALDEZ GÓES DA SILVA
# 3  Amazonas          13    amazonense                     WILSON MIRANDA LIMA
# 4     Bahia          29        baiano                    RUI COSTA DOS SANTOS
#
#   Capital [2010]  Área Territorial - km² [2019]  \
# 0     Rio Branco                      164123.96
# 1         Maceió                       27843.29
# 2         Macapá                      142470.76
# 3         Manaus                     1559167.89
# 4       Salvador                      564760.43
#
#    População estimada - pessoas [2020]  \
# 0                               894470
# 1                              3351543
# 2                               861773
# 3                              4207714
# ...

# %%
dados_ibge.columns
# Out:
# Index(['UF [-]', 'Código [-]', 'Gentílico [-]', 'Governador [2019]',
#        'Capital [2010]', 'Área Territorial - km² [2019]',
#        'População estimada - pessoas [2020]',
#        'Densidade demográfica - hab/km² [2010]',
#        'Matrículas no ensino fundamental - matrículas [2018]',
#        'IDH <span>Índice de desenvolvimento humano</span> [2010]',
#        'Receitas realizadas - R$ (×1000) [2017]',
#        'Despesas empenhadas - R$ (×1000) [2017]',
#        'Rendimento mensal domiciliar per capita - R$ [2019]',
#        'Total de veículos - veículos [2018]'],
#       dtype='object')

# %%
#concatenando cód + uf pra gerar unidade da federação no mesmo padrão do outro df
dados_ibge['Unidade da Federação'] = dados_ibge[['Código [-]', 'UF [-]']].apply(lambda x: ' '.join(x.values.astype(str)), axis=1)
dados_ibge['Unidade da Federação'].head()
dados_ibge = dados_ibge.set_index('Unidade da Federação')
dados_ibge.head(1)
# Out:
#                      UF [-]  Código [-] Gentílico [-]       Governador [2019]  \
# Unidade da Federação
# 12 Acre                Acre          12       acriano  GLADSON DE LIMA CAMELI
#
#                      Capital [2010]  Área Territorial - km² [2019]  \
# Unidade da Federação
# 12 Acre                  Rio Branco                      164123.96
#
#                       População estimada - pessoas [2020]  \
# Unidade da Federação
# 12 Acre                                            894470
#
#                       Densidade demográfica - hab/km² [2010]  \
# Unidade da Federação
# 12 Acre                                                 4.47
#
#                       Matrículas no ensino fundamental - matrículas [2018]  \
# Unidade da Federação
# 12 Acre                                                          157646
#
#                       IDH <span>Índice de desenvolvimento humano</span> [2010]  \
# Unidade da Federação
# ...

# %%
ibge_pop_idh = dados_ibge[['População estimada - pessoas [2020]', 'IDH <span>Índice de desenvolvimento humano</span> [2010]']].copy()
ibge_pop_idh.rename(columns={'População estimada - pessoas [2020]':'populacao/2020',
                             'IDH <span>Índice de desenvolvimento humano</span> [2010]':'idh/2010'}, inplace=True)
ibge_pop_idh = ibge_pop_idh.sort_index()
ibge_pop_idh
# Out:
#                         populacao/2020  idh/2010
# Unidade da Federação
# 11 Rondônia                    1796460      0.69
# 12 Acre                         894470      0.66
# 13 Amazonas                    4207714      0.67
# 14 Roraima                      631181      0.71
# 15 Pará                        8690745      0.65
# 16 Amapá                        861773      0.71
# 17 Tocantins                   1590248      0.70
# 21 Maranhão                    7114598      0.64
# 22 Piauí                       3281480      0.65
# 23 Ceará                       9187103      0.68
# 24 Rio Grande do Norte         3534165      0.68
# 25 Paraíba                     4039277      0.66
# 26 Pernambuco                  9616621      0.67
# 27 Alagoas                     3351543      0.63
# 28 Sergipe                     2318822      0.67
# 29 Bahia                      14930634      0.66
# 31 Minas Gerais               21292666      0.73
# 32 Espírito Santo              4064052      0.74
# ...

# %%
#média dos gastos de cada estado 
media_gasto_estado = ordenado_por_total_normalizado.mean(axis=1)
media_gasto_estado
# Out:
# Unidade da Federação
# 35 São Paulo             250820809.21
# 31 Minas Gerais          125447846.68
# 41 Paraná                 90937599.91
# 43 Rio Grande do Sul      78797242.12
# 33 Rio de Janeiro         62560730.77
# 29 Bahia                  60514227.30
# 26 Pernambuco             52892230.65
# 42 Santa Catarina         48174900.32
# 23 Ceará                  40877445.93
# 52 Goiás                  30327820.10
# 15 Pará                   29219995.83
# 21 Maranhão               23889900.81
# 32 Espírito Santo         20684178.40
# 24 Rio Grande do Norte    16333025.73
# 25 Paraíba                16241846.87
# 53 Distrito Federal       15954336.64
# 50 Mato Grosso do Sul     14344474.04
# 22 Piauí                  14015416.93
# 27 Alagoas                13845568.46
# 51 Mato Grosso            13427789.97
# 13 Amazonas               11646928.12
# 28 Sergipe                 7462501.09
# 17 Tocantins               6585702.87
# 11 Rondônia                6150201.28
# ...

# %%
ibge_pop_idh['media/gasto'] = media_gasto_estado
ibge_pop_idh['gasto/populacao'] = ibge_pop_idh['media/gasto']/ibge_pop_idh['populacao/2020']
ibge_pop_idh['idh/2010'] = (ibge_pop_idh['idh/2010']*100)

# %%
ibge_pop_idh['idh/2010'] = ibge_pop_idh['idh/2010'].astype(int)

# %%
idh_por_gasto_medio = ibge_pop_idh[['gasto/populacao','idh/2010']].copy()
idh_por_gasto_medio = idh_por_gasto_medio.groupby('idh/2010', as_index=True)['gasto/populacao'].mean()
idh_por_gasto_medio
# Out:
# idh/2010
# 63   3.74
# 64   3.82
# 65   4.02
# 66   3.46
# 67   4.13
# 68   4.54
# 69   3.78
# 70   2.71
# 72   4.46
# 73   5.08
# 74   6.63
# 76   3.60
# 77   6.64
# 78   5.42
# 82   5.22
# Name: gasto/populacao, dtype: float64

# %%
ax = idh_por_gasto_medio.plot(kind='barh', figsize=(10,10))
plt.title('IDH por gasto médico médio populacional', fontsize=16)
plt.xticks(rotation=0)
ax.set_xlabel('Proporção de gasto populacional', fontsize=14)
ax.set_ylabel('IDH em anos', fontsize=14)
# Out:
# Text(0, 0.5, 'IDH em anos')

# %%
gastos_proporcionais = gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.sum()
gastos_proporcionais.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
ibge_estimativa = pd.read_excel("https://github.com/alura-cursos/agendamento-hospitalar/raw/main/dados/estimativa_dou_2020.xls")
ibge_estimativa.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  \
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO
# 1                                             Brasil
# 2                                       Região Norte
# 3                                           Rondônia
# 4                                               Acre
#
#    Unnamed: 1          Unnamed: 2
# 0         nan  POPULAÇÃO ESTIMADA
# 1         nan           211755692
# 2         nan            18672591
# 3         nan             1796460
# 4         nan              894470

# %%
dados_da_populacao = """Posição    Unidade federativa    População    % da pop. total    País comparável
1    São Paulo    46 289 333    21,9%    Flag of Spain.svg Espanha (46 439 864)
2    Minas Gerais    21 292 666    10,1%     Sri Lanka (20 675 000)
3    Rio de Janeiro    17 366 189    8,2%     Países Baixos (16 922 900)
4    Bahia Bahia    14 930 634    7,1%     Chade (14 037 000)
5    Paraná    11 516 840    5,4%     Bolívia (11 410 651)
6    Rio Grande do Sul    11 422 973    5,4%     Bélgica (11 250 659)
7    Pernambuco    9 616 621    4,5%     Bielorrússia (9 485 300)
8    Ceará    9 187 103    4,3%     Emirados Árabes Unidos (9 157 000)
9    Pará Pará    8 690 745    4,1%     Áustria (8 602 112)
10    Santa Catarina    7 252 502    3,4%     Sérvia (7 114 393)
11    Maranhão    7 114 598    3,4%     Paraguai (7 003 406)
12    Goiás    7 113 540    3,4%     Paraguai (7 003 406)
13    Amazonas    4 207 714    2,0%     Líbano (4 168 000)
14    Espírito Santo    4 064 052    1,9%     Líbano (4 168 000)
15    Paraíba    4 039 277    1,9%     Líbano (4 168 000)
16    Rio Grande do Norte    3 534 165    1,7%     Uruguai (3 415 866)
17    Mato Grosso    3 526 220    1,7%     Uruguai (3 415 866)
18    Alagoas    3 351 543    1,6%     Uruguai (3 415 866)
19    Piauí    3 281 480    1,6%     Kuwait (3 268 431)
20    Distrito Federal    3 055 149    1,4%     Lituânia (2 900 787)
21    Mato Grosso do Sul    2 809 394    1,3%     Jamaica (2 717 991)
22    Sergipe    2 318 822    1,1%     Namíbia (2 280 700)
23    Rondônia    1 796 460    0,8%     Gabão (1 725 000)
24    Tocantins    1 590 248    0,7%     Bahrein (1 359 800)
25    Acre    894 470    0,4%     Fiji (859 178)
26    Amapá    861 773    0,4%     Fiji (859 178)
27    Roraima    631 181    0,3%     Luxemburgo (562 958)"""

# %%
from io import StringIO

dados_da_populacao_io = StringIO(dados_da_populacao)

pd.read_csv(dados_da_populacao_io, sep="    ", engine='python')
# Out:
#     Posição   Unidade federativa   População % da pop. total  \
# 0         1            São Paulo  46 289 333           21,9%
# 1         2         Minas Gerais  21 292 666           10,1%
# 2         3       Rio de Janeiro  17 366 189            8,2%
# 3         4          Bahia Bahia  14 930 634            7,1%
# 4         5               Paraná  11 516 840            5,4%
# 5         6    Rio Grande do Sul  11 422 973            5,4%
# 6         7           Pernambuco   9 616 621            4,5%
# 7         8                Ceará   9 187 103            4,3%
# 8         9            Pará Pará   8 690 745            4,1%
# 9        10       Santa Catarina   7 252 502            3,4%
# 10       11             Maranhão   7 114 598            3,4%
# 11       12                Goiás   7 113 540            3,4%
# 12       13             Amazonas   4 207 714            2,0%
# 13       14       Espírito Santo   4 064 052            1,9%
# ...

# %% [markdown]
# ### Desafio: pegar tabela por html

# %%
url_wikipedia = 'https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o'
populacao_por_unidade_federativa = pd.read_html(url_wikipedia)
populacao_por_unidade_federativa = populacao_por_unidade_federativa[0]
populacao_por_unidade_federativa.head()
# Out:
#    Posição Unidade federativa   População % da pop. total  \
# 0        1          São Paulo  46 289 333           21,9%
# 1        2       Minas Gerais  21 292 666           10,1%
# 2        3     Rio de Janeiro  17 366 189            8,2%
# 3        4              Bahia  14 930 634            7,1%
# 4        5             Paraná  11 516 840            5,4%
#
#   País comparável (habitantes)
# 0         Espanha (46 439 864)
# 1       Sri Lanka (20 675 000)
# 2   Países Baixos (16 922 900)
# 3           Chade (14 037 000)
# 4         Bolívia (11 410 651)

# %%
# def transforma_populacao_numerico(populacao):
#     populacao = int(populacao.replace(" ", ""))
    
#     return populacao

# %%
# populacao_por_unidade_federativa['populacao'] = populacao_por_unidade_federativa['populacao'].apply(transforma_populacao_numerico)
# populacao_por_unidade_federativa['populacao']

# %%
def leitura_limpeza(tabelas):
    
    def transforma_populacao_numerico(pop):
        pop = pop.replace(" ", "")
        return int(pop)
    
    populacao = tabelas[0]
    gastos_do_mais_recente = tabelas[1]
    
    #trocar nomes das colunas
    populacao.rename(columns={'Unidade federativa':'uf', 'População': 'populacao'}, inplace=True)
    
    populacao['populacao'] = populacao['populacao'].apply(transforma_populacao_numerico)
    populacao = populacao_por_unidade_federativa[["populacao", "uf"]]
    populacao = populacao.set_index('uf')
    
    gastos_do_mais_recente.index = gastos_do_mais_recente.index.str[3:]
    tabela_unida = populacao.join(gastos_do_mais_recente)
    
    return [populacao, tabela_unida]

# %%
leitura_limpeza([populacao_por_unidade_federativa, gastos_do_mes_mais_recente])
# Out:
# [                     populacao
#  uf
#  São Paulo             46289333
#  Minas Gerais          21292666
#  Rio de Janeiro        17366189
#  Bahia                 14930634
#  Paraná                11516840
#  Rio Grande do Sul     11422973
#  Pernambuco             9616621
#  Ceará                  9187103
#  Pará                   8690745
#  Santa Catarina         7252502
#  Maranhão               7114598
#  Goiás                  7113540
#  Amazonas               4207714
#  Espírito Santo         4064052
#  Paraíba                4039277
#  Rio Grande do Norte    3534165
#  Mato Grosso            3526220
#  Alagoas                3351543
#  Piauí                  3281480
#  Distrito Federal       3055149
#  Mato Grosso do Sul     2809394
#  Sergipe                2318822
#  Rondônia               1796460
#  Tocantins              1590248
#  Acre                    894470
#  Amapá                   861773
#  Roraima                 631181,
# ...
